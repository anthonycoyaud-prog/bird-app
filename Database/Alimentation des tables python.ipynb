# %%
# Création des fichiers CSV pour chaque table

import pandas as pd
from datetime import datetime

# Table taxonomie
taxonomie = pd.DataFrame([
    [1, "Accipitriformes", "Accipitridae", "Aquila"],
    [2, "Sphenisciformes", "Spheniscidae", "Eudyptula"],
    [3, "Passeriformes", "Corvidae", "Corvus"],
    [4, "Strigiformes", "Strigidae", "Bubo"]
], columns=["id_taxonomie", "ordre", "famille", "genre"])

# Table caracteristique_physique
caracteristique_physique = pd.DataFrame([
    [1, 90, 3630, 6700, 25],
    [2, 39, 500, 750, 20],
    [3, 65, 800, 1600, 15],
    [4, 65, 2000, 3000, 20] # Nouvelle entrée pour Hibou Grand-duc
], columns=["id_caracteristique", "taille_cm", "poids_min_g", "poids_max_g", "longevite_ans"])

# Table population_repartition
population_repartition = pd.DataFrame([
    [1, 250, "Europe"],
    [2, 300, "Australie"],
    [3, 1000000, "Mondial"],
    [4, 50000, "Eurasie"] # Nouvelle entrée pour Hibou Grand-duc
], columns=["id_population", "population_estimee", "zone_geographique"])

# Table oiseau
oiseau = pd.DataFrame([
    [1, "Aigle royal", "Grand rapace majestueux", 1, 1, 1],
    [2, "Petit Pingouin", "Plus petit manchot du monde", 2, 2, 2],
    [3, "Corbeau commun", "Oiseau intelligent et adaptable", 3, 3, 3],
    [4, "Hibou Grand-duc", "Grand rapace nocturne", 4, 4, 4] # Nouvelle entrée
], columns=["id_oiseau", "nom_commun", "description", "id_taxonomie", "id_caracteristique", "id_population"])

# Table auteur
auteur = pd.DataFrame([
    [1, "Dupont", "Jean", "jean.dupont@email.com"],
    [2, "Martin", "Claire", "claire.martin@email.com"]
], columns=["id_auteur", "nom", "prenom", "email"])

# Table auteur_oiseau
auteur_oiseau = pd.DataFrame([
    [1, 1],
    [2, 2],
    [1, 3]
], columns=["id_auteur", "id_oiseau"])

# Table pays
pays = pd.DataFrame([
    [1, "France"],
    [2, "Australie"],
    [3, "États-Unis"]
], columns=["id_pays", "nom_pays"])

# Table oiseau_pays
oiseau_pays = pd.DataFrame([
    [1, 1],
    [2, 2],
    [3, 1],
    [3, 3]
], columns=["id_oiseau", "id_pays"])

# Table image
image = pd.DataFrame([
    [1, "https://www.istockphoto.com/photo/soon-eagle-gm148292678-20800839?utm_source=pixabay&utm_medium=affiliate&utm_campaign=sponsored_image&utm_content=srp_topbanner_media&utm_term=aigle", datetime.now(), 1],
    [2, "https://www.istockphoto.com/photo/gentoo-penguin-waddling-along-on-a-white-sand-beach-gm511366776-86619255?utm_source=pixabay&utm_medium=affiliate&utm_campaign=sponsored_image&utm_content=srp_topbanner_media&utm_term=pingouin", datetime.now(), 2],
    [3, "https://www.istockphoto.com/photo/raven-in-black-white-isolated-gm173542839-7590722?utm_source=pixabay&utm_medium=affiliate&utm_campaign=sponsored_image&utm_content=srp_topbanner_media&utm_term=corbeau", datetime.now(), 3]
], columns=["id_image", "url_image", "date_upload", "id_oiseau"])

# Sauvegarde des fichiers CSV
taxonomie.to_csv("/taxonomie.csv", index=False)
caracteristique_physique.to_csv("/caracteristique_physique.csv", index=False)
population_repartition.to_csv("/population_repartition.csv", index=False)
oiseau.to_csv("/oiseau.csv", index=False)
auteur.to_csv("/auteur.csv", index=False)
auteur_oiseau.to_csv("/auteur_oiseau.csv", index=False)
pays.to_csv("/pays.csv", index=False)
oiseau_pays.to_csv("/oiseau_pays.csv", index=False)
image.to_csv("/image.csv", index=False)

print("Fichiers CSV générés avec succès.")
# Out:
# Fichiers CSV générés avec succès.

# %%
from google.colab import files

# Liste des fichiers CSV à télécharger
csv_files = [
    "/taxonomie.csv",
    "/caracteristique_physique.csv",
    "/population_repartition.csv",
    "/oiseau.csv",
    "/auteur.csv",
    "/auteur_oiseau.csv",
    "/pays.csv",
    "/oiseau_pays.csv",
    "/image.csv"
]

# Télécharger chaque fichier
for file_path in csv_files:
    try:
        files.download(file_path)
        print(f"Le fichier {file_path} a été téléchargé.")
    except Exception as e:
        print(f"Erreur lors du téléchargement de {file_path}: {e}")
# Out:
# Le fichier /taxonomie.csv a été téléchargé.
# Le fichier /caracteristique_physique.csv a été téléchargé.
# Le fichier /population_repartition.csv a été téléchargé.
# Le fichier /oiseau.csv a été téléchargé.
# Le fichier /auteur.csv a été téléchargé.
# Le fichier /auteur_oiseau.csv a été téléchargé.
# Le fichier /pays.csv a été téléchargé.
# Le fichier /oiseau_pays.csv a été téléchargé.
# Le fichier /image.csv a été téléchargé.
